# %%
import statsmodels.tools.eval_measures as sm
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import os

# %%
df = pd.read_csv('../data/Homelessness Reports/homelessness_reports.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Region', 'Total Adults', 'Male Adults', 'Female Adults',
#        'Adults Aged 18-24', 'Adults Aged 25-44', 'Adults Aged 45-64',
#        'Adults Aged 65+',
#        'Number of people who accessed Private Emergency Accommodation',
#        'Number of people who accessed Supported Temporary Accommodation',
#        'Number of people who accessed Temporary Emergency Accommodation',
#        'Number of people who accessed Other Accommodation',
#        'Number of Families', 'Number of Adults in Families',
#        'Number of Single-Parent families', 'Number of Dependants in Families',
#        'month', 'year', 'Number of Child Dependants in Families',
#        'Number of people with citizenship Irish',
#        'Number of people with citizenship EEA/Uk',
#        'Number of people with citizenship Non-EEA'],
#       dtype='object')

# %%
cols = ['year', 
        'month', 
        'Region', 
        'Total Adults', 
        'Male Adults', 
        'Female Adults', 
        'Adults Aged 18-24', 
        'Adults Aged 25-44', 
        'Adults Aged 45-64',
        'Adults Aged 65+',
        'Number of Families',
        'Number of Adults in Families',
        'Number of Dependants in Families',
        'Number of Child Dependants in Families',
        'Number of people with citizenship Irish',
        'Number of people with citizenship EEA/Uk',
        'Number of people with citizenship Non-EEA']

df = df[cols]

# %%
df
# Out:
#      year month      Region Total Adults Male Adults Female Adults  \
# 0    2019   nov      Dublin        4,509       2,636         1,873
# 1    2019   nov    Mid-East          322         197           125
# 2    2019   nov    Midlands           97          45            52
# 3    2019   nov    Mid-West          369         222           147
# 4    2019   nov  North-East          141          85            56
# ..    ...   ...         ...          ...         ...           ...
# 427  2022   mar  North-East           84          59            25
# 428  2022   mar  North-West           77          49            28
# 429  2022   mar  South-East          246         175            71
# 430  2022   mar  South-West          570         401           169
# 431  2022   mar        West          331         197           134
#
#      Adults Aged 18-24 Adults Aged 25-44 Adults Aged 45-64  Adults Aged 65+  \
# 0                  557             2,635             1,228               89
# ...

# %%
df_dublin = df[df['Region'].str.contains('Dublin')]

# %%
df_dublin
# Out:
#      year month  Region Total Adults Male Adults Female Adults  \
# 0    2019   nov  Dublin        4,509       2,636         1,873
# 9    2019   aug  Dublin        4,312       2,447         1,865
# 18   2019   dec  Dublin        4,268       2,498         1,770
# 27   2019   may  Dublin        4,367       2,542         1,825
# 36   2019   jun  Dublin        4,356       2,529         1,827
# 45   2019   jul  Dublin        4,300       2,448         1,852
# 54   2019   apr  Dublin        4,401       2,538         1,863
# 63   2019   feb  Dublin        4,304       2,452         1,852
# 72   2019   mar  Dublin        4,315       2,465         1,850
# 81   2019   jan  Dublin        4,258       2,428         1,830
# 90   2019   oct  Dublin        4,534       2,658         1,876
# 99   2019   sep  Dublin        4,370       2,486         1,884
# 108  2020   dec  Dublin         4158        2681          1477
# 117  2020   aug  Dublin         4204        2695          1509
# ...

# %%
df_dublin['Number of Dependants in Families'] = df['Number of Dependants in Families'].fillna(df['Number of Child Dependants in Families'])
# Out:
# /var/folders/fq/w4n1nx9n5flfw6tv_nzn8kyr0000gn/T/ipykernel_24611/1754264154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dublin['Number of Dependants in Families'] = df['Number of Dependants in Families'].fillna(df['Number of Child Dependants in Families'])

# %%
df_dublin.pop('Number of Child Dependants in Families')
# Out:
# 0        NaN
# 9        NaN
# 18       NaN
# 27       NaN
# 36       NaN
# 45       NaN
# 54       NaN
# 63       NaN
# 72       NaN
# 81       NaN
# 90       NaN
# 99       NaN
# 108      NaN
# 117      NaN
# 126      NaN
# 135      NaN
# 144      NaN
# 153      NaN
# 162      NaN
# 171      NaN
# 180      NaN
# 189      NaN
# 198      NaN
# 207      NaN
# 216      NaN
# 225      NaN
# 234      NaN
# 243      NaN
# 252      NaN
# 261      NaN
# 270      NaN
# 279      NaN
# 288      NaN
# 297      NaN
# 306      NaN
# 315    1,806
# 324      NaN
# 333      NaN
# 342      NaN
# 351      NaN
# 360      NaN
# 369      NaN
# 378      NaN
# 387      NaN
# 396      NaN
# 405      NaN
# 414      NaN
# 423      NaN
# Name: Number of Child Dependants in Families, dtype: object

# %%
df_dublin.to_csv('./homelessness_dublin.csv')

# %% [markdown]
# #### 3. Population Data a) Age

# %%
ls
# Out:
# p_moved_outside_dublin_2011-2022.csv
# p_per_household_all.csv
# population_age_2002-2022.csv
# population_age_2011-2016.csv
# population_age_2022.csv
# population_non-national_2002.csv
# population_non-national_2006.csv
# population_non-national_2011.csv
# population_non_national_2011-2016.csv
# population_perc_change_regional_2006.csv
# population_percentage_change_2002-2006.csv
# population_percentage_change_2011-2022.csv

# %%
df2 = pd.read_csv('./population_age_2002-2022.csv')
df2
# Out:
#                Statistic Label  CensusYear          Age Group         Sex  \
# 0    Population at Each Census        1926           All ages  Both sexes
# 1    Population at Each Census        1926           All ages        Male
# 2    Population at Each Census        1926           All ages      Female
# 3    Population at Each Census        1926        0 - 4 years  Both sexes
# 4    Population at Each Census        1926        0 - 4 years        Male
# ..                         ...         ...                ...         ...
# 964  Population at Each Census        2022      80 - 84 years        Male
# 965  Population at Each Census        2022      80 - 84 years      Female
# 966  Population at Each Census        2022  85 years and over  Both sexes
# 967  Population at Each Census        2022  85 years and over        Male
# 968  Population at Each Census        2022  85 years and over      Female
#
#        UNIT    VALUE
# 0    Number  2971992
# 1    Number  1506889
# ...

# %%
df2.pop('Statistic Label')
# Out:
# 0      Population at Each Census
# 1      Population at Each Census
# 2      Population at Each Census
# 3      Population at Each Census
# 4      Population at Each Census
#                  ...
# 964    Population at Each Census
# 965    Population at Each Census
# 966    Population at Each Census
# 967    Population at Each Census
# 968    Population at Each Census
# Name: Statistic Label, Length: 969, dtype: object

# %%
df2.pop('UNIT')
# Out:
# 0      Number
# 1      Number
# 2      Number
# 3      Number
# 4      Number
#         ...
# 964    Number
# 965    Number
# 966    Number
# 967    Number
# 968    Number
# Name: UNIT, Length: 969, dtype: object

# %%
df2 = df2[df2['CensusYear'] > 1996]
df2
# Out:
#      CensusYear          Age Group         Sex    VALUE
# 684        2002           All ages  Both sexes  3917203
# 685        2002           All ages        Male  1946164
# 686        2002           All ages      Female  1971039
# 687        2002        0 - 4 years  Both sexes   277630
# 688        2002        0 - 4 years        Male   142040
# ..          ...                ...         ...      ...
# 964        2022      80 - 84 years        Male    43588
# 965        2022      80 - 84 years      Female    52998
# 966        2022  85 years and over  Both sexes    84441
# 967        2022  85 years and over        Male    31607
# 968        2022  85 years and over      Female    52834
#
# [285 rows x 4 columns]

# %%
df3 = pd.read_csv('./pop_estimates.csv')
df3
# Out:
#                       STATISTIC Label  Year Single Year of Age         Sex  \
# 0      Population estimates from 1926  1926           All ages  Both sexes
# 1      Population estimates from 1926  1926           All ages        Male
# 2      Population estimates from 1926  1926           All ages      Female
# 3      Population estimates from 1926  1926       Under 1 year  Both sexes
# 4      Population estimates from 1926  1926       Under 1 year        Male
# ...                               ...   ...                ...         ...
# 11509  Population estimates from 1926  2022           98 years        Male
# 11510  Population estimates from 1926  2022           98 years      Female
# 11511  Population estimates from 1926  2022  99 years and over  Both sexes
# 11512  Population estimates from 1926  2022  99 years and over        Male
# 11513  Population estimates from 1926  2022  99 years and over      Female
#
#          UNIT    VALUE
# 0      Number  2971992
# ...

# %%
df3 = df3[(df3['Year'] == 2019)|(df3['Year'] == 2020)|(df3['Year'] == 2021)]

# %%
df3.columns = df3.columns.str.lower()

# %%
df3.rename(columns={'single year of age':'age group'}, inplace=True)
# Out:
# /var/folders/fq/w4n1nx9n5flfw6tv_nzn8kyr0000gn/T/ipykernel_60830/211800179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.rename(columns={'single year of age':'age group'}, inplace=True)

# %%
df3.pop('statistic label')
# Out:
# 10302    Population estimates from 1926
# 10303    Population estimates from 1926
# 10304    Population estimates from 1926
# 10305    Population estimates from 1926
# 10306    Population estimates from 1926
#                       ...
# 11206    Population estimates from 1926
# 11207    Population estimates from 1926
# 11208    Population estimates from 1926
# 11209    Population estimates from 1926
# 11210    Population estimates from 1926
# Name: statistic label, Length: 909, dtype: object

# %%
df3.pop('unit')
# Out:
# 10302    Number
# 10303    Number
# 10304    Number
# 10305    Number
# 10306    Number
#           ...
# 11206    Number
# 11207    Number
# 11208    Number
# 11209    Number
# 11210    Number
# Name: unit, Length: 909, dtype: object

# %%
df3 = df3[(df3['age group'] == 'All ages')&(df3['sex'] == 'Both sexes')]

# %%
df3
# Out:
#        year age group         sex    value
# 10302  2019  All ages  Both sexes  4921496
# 10605  2020  All ages  Both sexes  4977443
# 10908  2021  All ages  Both sexes  5011460

# %%
df4 = pd.read_csv('population_age_all.csv')

# %%
df4 = df4[df4['age group'] == 'All ages']

# %%
df4
# Out:
#     Unnamed: 0  year age group    value
# 0            0  2002  All ages  3917203
# 19          57  2006  All ages  4239848
# 38         114  2011  All ages  4588252
# 57         171  2016  All ages  4761865
# 76         228  2022  All ages  5149139

# %%
df5 = df4.merge(df3, how='outer', on=['year', 'age group', 'value'])

# %%
df5.pop('sex')
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5    Both sexes
# 6    Both sexes
# 7    Both sexes
# Name: sex, dtype: object

# %%
df5.pop('Unnamed: 0')
# Out:
# 0      0.0
# 1     57.0
# 2    114.0
# 3    171.0
# 4    228.0
# 5      NaN
# 6      NaN
# 7      NaN
# Name: Unnamed: 0, dtype: float64

# %%
df5.to_csv('population_totals.csv', index=False)
